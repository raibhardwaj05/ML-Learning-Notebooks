# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

import plotly.express as px
import cufflinks as cf 

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load data

# %%
# !pip install charset-normalizer
# Out:
# Requirement already satisfied: charset-normalizer in c:\users\sachin\anaconda3\lib\site-packages (3.3.2)

# %%
from charset_normalizer import from_path # to automatically check the type of encoding

result = from_path("../data/netflix_titles.csv")
print(result.best().encoding)
# Out:
# utf_8

# %%
df_og = pd.read_csv("../data/netflix_titles.csv", encoding= result.best().encoding)
df_og.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %%
df_og.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df = df_og.copy()
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Preliminary Exploratory Data Analysis

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# ### Handling missing data

# %%
df['director'] = df['director'].fillna('unknown')
df['cast'] = df['cast'].fillna('unknown')
df['country'] = df['country'].fillna('unknown')
df['date_added'] = df['date_added'].fillna(df['date_added'].mode()[0])

# %%
df['date_added_format'] = pd.to_datetime(df['date_added'], errors= 'coerce')

# %%
movie_rating = df[df['type'] == 'Movie']['rating'].mode()[0]
movie_rating
# Out:
# 'TV-MA'

# %%
tv_rating = df[df['type'] == 'TV Show']['rating'].mode()[0]
tv_rating
# Out:
# 'TV-MA'

# %%
df.loc[
    (df['type'] == 'Movie') & (df['rating'].isna()), 
    'rating'] = movie_rating

# %%
df.loc[
    (df['type'] == 'TV Show') & (df['rating'].isna()),
    'rating'
] = tv_rating

# %%
df['time'] = df['duration'].str.extract('(\d+)').astype(float) # (\d+) means “extract one or more consecutive digits”
df['time']
# Out:
# 0        90.0
# 1         2.0
# 2         1.0
# 3         1.0
# 4         2.0
#         ...
# 8802    158.0
# 8803      2.0
# 8804     88.0
# 8805     88.0
# 8806    111.0
# Name: time, Length: 8807, dtype: float64

# %%
df['Movie Time'] = df.loc[df['type'] == 'Movie', 'time']
df['TV time'] = df.loc[df['type'] == 'TV Show', 'time']

# %%
df.rename(columns={'Movie Time' : 'Movie Duration',
                  'TV time' : 'TV seasons'}, inplace= True)

# %%
df.drop(columns= 'time', inplace= True)

# %%
df.isna().sum()
# Out:
# show_id                 0
# type                    0
# title                   0
# director                0
# cast                    0
# country                 0
# date_added              0
# release_year            0
# rating                  0
# duration                3
# listed_in               0
# description             0
# date_added_format      88
# Movie Duration       2679
# TV seasons           6131
# dtype: int64

# %%
df[['duration', 'Movie Duration', 'TV seasons']].sample(10)
# Out:
#        duration  Movie Duration  TV seasons
# 1692  2 Seasons             NaN         2.0
# 6769     83 min            83.0         NaN
# 7018    116 min           116.0         NaN
# 7904    110 min           110.0         NaN
# 2708  2 Seasons             NaN         2.0
# 2281    129 min           129.0         NaN
# 8653  4 Seasons             NaN         4.0
# 5886     85 min            85.0         NaN
# 3625    102 min           102.0         NaN
# 5752   1 Season             NaN         1.0

# %%
# since all the data in the TV seasons and Movie Duration match with duration, we can safely drop it
df.drop(columns='duration', inplace= True)

# %%
df['date_added'] = df['date_added_format']

# %%
df.drop(columns= 'date_added_format', inplace= True)

# %%
df.isna().sum()
# Out:
# show_id              0
# type                 0
# title                0
# director             0
# cast                 0
# country              0
# date_added          88
# release_year         0
# rating               0
# listed_in            0
# description          0
# Movie Duration    2679
# TV seasons        6131
# dtype: int64

# %%
df.rename(columns={
    'Movie Duration' : 'movie_duration_min',
    'TV seasons' : 'tv_seasons'
}, inplace= True)

# %%
df.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          unknown
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                            unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
#
#   date_added  release_year rating  \
# 0 2021-09-25          2020  PG-13
# 1 2021-09-24          2021  TV-MA
# 2 2021-09-24          2021  TV-MA
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  movie_duration_min  \
# 0  As her father nears the end of his life, filmm...                90.0
# 1  After crossing paths at a party, a Cape Town t...                 NaN
# 2  To protect his family from a powerful drug lor...                 NaN
#
#    tv_seasons
# 0         NaN
# 1         2.0
# 2         1.0

# %%
df.to_csv('../data/netflix_titles_cleaned.csv', index= False)

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR',
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
df['rating'].str.contains('min')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: rating, Length: 8807, dtype: bool

# %%
mask = df['rating'].isin(['74 min', '84 min', '66 min'])
df[mask]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating listed_in  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min    Movies
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min    Movies
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min    Movies
#
#                                             description  movie_duration_min  \
# 5541  Louis C.K. muses on religion, eternal love, gi...                 NaN
# 5794  Emmy-winning comedy writer Louis C.K. brings h...                 NaN
# 5813  The comic puts his trademark hilarious/thought...                 NaN
#
#       tv_seasons
# 5541         NaN
# 5794         NaN
# 5813         NaN

# %%
df.loc[mask, 'duration'] = df.loc[mask, 'rating']

# %%
df.loc[mask, 'rating'] = np.nan

# %%
df.loc[mask, ['rating', 'duration']]
# Out:
#      rating duration
# 5541    NaN   74 min
# 5794    NaN   84 min
# 5813    NaN   66 min

# %%
df.shape
# Out:
# (8807, 14)

# %% [markdown]
# ### extracting required data

# %%
# create new dataframe for all types of genres

genre_df = df.assign(
    genre = df['listed_in'].str.split(', ')
).explode('genre')

genre_df['genre'] = genre_df['genre'].str.strip()

# %%
genre_df.head(5)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water          unknown
# 1      s2  TV Show         Blood & Water          unknown
# 1      s2  TV Show         Blood & Water          unknown
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                            unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
#
#   date_added  release_year rating  \
# 0 2021-09-25          2020  PG-13
# 1 2021-09-24          2021  TV-MA
# 1 2021-09-24          2021  TV-MA
# 1 2021-09-24          2021  TV-MA
# 2 2021-09-24          2021  TV-MA
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  movie_duration_min  \
# 0  As her father nears the end of his life, filmm...                90.0
# 1  After crossing paths at a party, a Cape Town t...                 NaN
# 1  After crossing paths at a party, a Cape Town t...                 NaN
# 1  After crossing paths at a party, a Cape Town t...                 NaN
# 2  To protect his family from a powerful drug lor...                 NaN
#
#    tv_seasons duration                   genre
# 0         NaN      NaN           Documentaries
# 1         2.0      NaN  International TV Shows
# 1         2.0      NaN               TV Dramas
# 1         2.0      NaN            TV Mysteries
# 2         1.0      NaN          Crime TV Shows

# %% [markdown]
# ### Analysis based on these questions

# %% [raw]
# movie / tv which has longest duration
# who was the director and what was it's releasing year
#
# director who makes more shows, movies
# country which has more movies or shows
# country vs rating
# rating vs type
# genere vs rating
# country vs genre
# genre vs timeline
#
#
# which one is more movies or shows
# trends on timeline based on the rating
#
# movies vs shows trends on timeline
#
# average movie duration in a year
# increase in duration over time
